# %%
import matplotlib.pyplot as plt
import os
import pandas as pd
import numpy as np

# %%
workdir = '../personality-prediction-from-text'
results_t1 = os.path.join(workdir, 'data_output_dataset_trait_activating_answers_3')

# %%
results_dirs = [results_t3]

# %%
for r_dir in results_dirs:
     for i in range(10):
        x_path = os.path.join(r_dir,f'prediction_{i}.xlsx')
        if not os.path.exists(x_path):
            print(x_path)

# %%
from tqdm import tqdm
all_df={}
for r_dir in tqdm(results_dirs):
    
    df = []
    for i in range(10):
        path = os.path.join(r_dir,f'prediction_{i}.xlsx')
        if os.path.exists(path):
            df.append(pd.read_excel(path))
    
    df = pd.concat(df) 
    df['pred_sES'] = df['pred_sNEU'].apply(lambda x:5-x)
    df['pred_cES'] = df['pred_cNEU']
    all_df[r_dir]=df
# Out:
# 100%|██████████| 3/3 [02:20<00:00, 46.87s/it]

# %%
# !rm -rf output_trait_activating_answers

# %%
output_folder='output_trait_activating_answers'
os.makedirs(output_folder, exist_ok=True)
output_sent_folder = {}
for nsent in range(1,len(results_dirs)+1):
    output_sent_folder[nsent] = os.path.join(output_folder,f'sents_{nsent}')
    os.makedirs(output_sent_folder[nsent], exist_ok=True)

# %% [markdown]
# # Average Personality for each Model

# %%
traits = ['OPN', 'CON', 'EXT', 'AGR', 'NEU']
traits_ok = ['OPN', 'CON', 'EXT', 'AGR', 'ES']
categories = ['Openness', 'Conscientiousness', 'Extraversion', 'Agreeableness', 'Emotional stability']
model_names = ['gpt2','gpt2_medium','gpt2_large','op_125m','op_350m','op_13b', 'xlnet', 'xlnet_large']

all_xvalues = {}

for r_index,r_dir in enumerate(results_dirs):
    all_xvalues[r_index+1] = {}
    df = all_df[r_dir]
    
    for k,g in enumerate(model_names):
        
        gdf=df[df['model_name']==g]
        
        xmvalues = []
        xvvalues = []
        for i,(cat,trait) in enumerate(zip(categories, traits_ok)):
            
            x = gdf[gdf['category']==cat]['pred_s'+trait].values
            xmvalues.append(np.mean(x))
            xvvalues.append(np.std(x))
            
        all_xvalues[r_index+1][k] = {'mean':xmvalues,'std':xvvalues}

# %%
names = list(map(lambda x:x[0],traits_ok))

# %%
fig, axs = plt.subplots(len(model_names),1, sharex=False, sharey=False, figsize=(15,30), frameon=False)
#fig.subplots_adjust(left=0.25)   
colors = ['g','b','k']
width = 0.27
for k,model in enumerate(model_names):
    ind = np.arange(5) 
    rects = []
    for n in range(3):
        vals = np.array(all_xvalues[n+1][k]['mean'])
        err = np.array(all_xvalues[n+1][k]['std'])
        rect = axs[k].bar(ind+width*n, vals, width, yerr=err, color=colors[n])
        rects.append(rect)
    
    axs[k].set_title(model)
    
    axs[k].set_ylabel('Scores')
    axs[k].set_xticks(ind+width)
    axs[k].set_xticklabels( names )
    axs[k].legend( (rects[0][0], rects[1][0], rects[2][0]), ('1 sent', '2 sents', '3 sents') )
plt.savefig(os.path.join(output_folder, f'personality_by_nsents.jpg'))

# %% [markdown]
# # Higher and Lower Scores Examples

# %%
traits = ['OPN', 'CON', 'EXT', 'AGR', 'NEU']
traits_ok = ['OPN', 'CON', 'EXT', 'AGR', 'ES']
categories = ['Openness', 'Conscientiousness', 'Extraversion', 'Agreeableness', 'Emotional stability']
model_names = ['gpt2','gpt2_medium','gpt2_large','op_125m','op_350m','op_13b', 'xlnet', 'xlnet_large']
all_examples = {}

for r_index,r_dir in enumerate(results_dirs):
    df = all_df[r_dir]   
    all_examples[r_index+1] = {}    
    for k,g in enumerate(model_names):
        
        gdf=df[df['model_name']==g]
        
        examples = {}
        for i,(cat,trait) in enumerate(zip(categories, traits_ok)):

            xdf = gdf[gdf['category']==cat].sort_values(by='pred_s'+trait, ascending=False)
            
            higher = xdf.iloc[:3][['text','pred_s'+trait]]
            lower  = xdf.iloc[-3:][['text','pred_s'+trait]]
            
            examples[trait] = {'higher':higher, 'lower':lower}
            
        all_examples[r_index+1][k] = examples

# %%
for nsent in range(1,4):
    for case_name in ['higher','lower']:
        for trait in traits_ok:
            path = os.path.join(output_sent_folder[nsent], f"trait_{trait}_{case_name}.xlsx")            
            table = []
            for k,m in enumerate(model_names):
                case = all_examples[nsents][k][trait]['higher']
                for _,row in case.iterrows():
                    trow = {'score':row['pred_s'+trait] , 'text':row['text'], 'model':m}
                    table.append(trow)
            table = pd.DataFrame(table)
            table.to_excel(path)

# %% [markdown]
# # Histograms

# %%
import matplotlib.pyplot as plt
traits = ['OPN', 'CON', 'EXT', 'AGR', 'NEU']
traits_ok = ['OPN', 'CON', 'EXT', 'AGR', 'ES']
categories = ['Openness', 'Conscientiousness', 'Extraversion', 'Agreeableness', 'Emotional stability']

for r_index,r_dir in enumerate(results_dirs):
    df = all_df[r_dir]   
        
    for k,g in enumerate(model_names):

        gdf=df[df['model_name']==g]
        
        plt.figure(figsize=(10,20))

        for i,(cat,trait) in enumerate(zip(categories, traits_ok)):
            #print(cat,trait)
            plt.subplot(len(categories),1,i+1)
            x = gdf[gdf['category']==cat]['pred_s'+trait].values
            plt.hist(x)
            plt.title(cat)
            plt.xlim([1,5])
            
        plt.savefig(os.path.join(output_sent_folder[r_index+1], f'model_{g}.jpg'))
# Out:
# Openness OPN
# Conscientiousness CON
# Extraversion EXT
# Agreeableness AGR
# Emotional stability ES
# Openness OPN
# Conscientiousness CON
# Extraversion EXT
# Agreeableness AGR
# Emotional stability ES
# Openness OPN
# Conscientiousness CON
# Extraversion EXT
# Agreeableness AGR
# Emotional stability ES
# Openness OPN
# Conscientiousness CON
# Extraversion EXT
# Agreeableness AGR
# Emotional stability ES
# Openness OPN
# Conscientiousness CON
# Extraversion EXT
# Agreeableness AGR
# Emotional stability ES
# Openness OPN
# Conscientiousness CON
# Extraversion EXT
# Agreeableness AGR
# Emotional stability ES
# Openness OPN
# Conscientiousness CON
# Extraversion EXT
# Agreeableness AGR
# Emotional stability ES
# Openness OPN
# Conscientiousness CON
# Extraversion EXT
# Agreeableness AGR
# Emotional stability ES
# Openness OPN
# Conscientiousness CON
# Extraversion EXT
# Agreeableness AGR
# Emotional stability ES
# Openness OPN
# Conscientiousness CON
# Extraversion EXT
# Agreeableness AGR
# Emotional stability ES
# Openness OPN
# Conscientiousness CON
# Extraversion EXT
# Agreeableness AGR
# Emotional stability ES
# Openness OPN
# Conscientiousness CON
# Extraversion EXT
# Agreeableness AGR
# Emotional stability ES
# Openness OPN
# Conscientiousness CON
# Extraversion EXT
# Agreeableness AGR
# Emotional stability ES
# Openness OPN
# Conscientiousness CON
# Extraversion EXT
# Agreeableness AGR
# Emotional stability ES
# Openness OPN
# Conscientiousness CON
# Extraversion EXT
# Agreeableness AGR
# Emotional stability ES
# Openness OPN
# Conscientiousness CON
# Extraversion EXT
# Agreeableness AGR
# Emotional stability ES
# Openness OPN
# Conscientiousness CON
# Extraversion EXT
# Agreeableness AGR
# Emotional stability ES
# Openness OPN
# Conscientiousness CON
# Extraversion EXT
# Agreeableness AGR
# Emotional stability ES
# Openness OPN
# Conscientiousness CON
# Extraversion EXT
# Agreeableness AGR
# Emotional stability ES
# Openness OPN
# Conscientiousness CON
# Extraversion EXT
# Agreeableness AGR
# Emotional stability ES
# Openness OPN
# Conscientiousness CON
# Extraversion EXT
# Agreeableness AGR
# Emotional stability ES
# Openness OPN
# Conscientiousness CON
# Extraversion EXT
# Agreeableness AGR
# Emotional stability ES
# Openness OPN
# Conscientiousness CON
# Extraversion EXT
# Agreeableness AGR
# Emotional stability ES
# Openness OPN
# Conscientiousness CON
# Extraversion EXT
# Agreeableness AGR
# Emotional stability ES

# %% [markdown]
# # Bar chart for each category

# %%
import matplotlib.pyplot as plt
import numpy as np

traits = ['OPN', 'CON', 'EXT', 'AGR', 'NEU']
traits_ok = ['OPN', 'CON', 'EXT', 'AGR', 'ES']
categories = ['Openness', 'Conscientiousness', 'Extraversion', 'Agreeableness', 'Emotional stability']

ind = np.arange(len(traits_ok))
for r_index,r_dir in enumerate(results_dirs):
    
    df = all_df[r_dir]
    
    for k,g in enumerate(model_names):

        gdf=df[df['model_name']==g]

        fig, axs = plt.subplots(5,1, sharex=False, sharey=False, figsize=(15,20), frameon=False)
        fig.subplots_adjust(left=0.25)
        
        for i,cat in enumerate(categories):
            cdf = gdf[gdf['category']==cat]
            scores = []
            for j,trait in enumerate(traits_ok):
                x = cdf['pred_c' + trait]
                if len(x)==0:
                    x=0
                else:
                    x = x.sum()/len(x)
                scores.append(x)
            #print(scores)
            axs[i].bar(ind, scores)
                     
            axs[i].set_title(cat)

            axs[i].set_xticks(ind)
            axs[i].set_xticklabels(traits_ok)
            axs[i].set_ylim([0,1])

        plt.savefig(os.path.join(output_sent_folder[r_index+1], f'model_{g}_clf_vs_groups.jpg'))
# Out:
# [0.971, 0.3576, 0.2402, 0.4164, 0.0722]
# [0.9744, 0.375, 0.1482, 0.7192, 0.0344]
# [0.9644, 0.2494, 0.1232, 0.61, 0.074]
# [0.9696, 0.2628, 0.1228, 0.6154, 0.1054]
# [0.9682, 0.3406, 0.2558, 0.559, 0.1132]
# [0.9774, 0.171, 0.0962, 0.6888, 0.076]
# [0.9726, 0.2038, 0.1052, 0.6558, 0.1064]
# [0.9668, 0.2326, 0.1648, 0.5946, 0.0912]
# [0.961, 0.2492, 0.1604, 0.6188, 0.1098]
# [0.9802, 0.1912, 0.102, 0.7504, 0.1034]
# [0.9372, 0.1576, 0.1102, 0.7568, 0.1674]
# [0.9706, 0.2518, 0.1114, 0.5946, 0.134]
# [0.9664, 0.238, 0.3164, 0.7472, 0.1308]
# [0.9664, 0.3438, 0.1316, 0.5634, 0.0546]
# [0.9582, 0.387, 0.122, 0.689, 0.0582]
# [0.9822, 0.2744, 0.1374, 0.7244, 0.0544]
# [0.968, 0.3178, 0.1198, 0.6806, 0.0948]
# [0.969, 0.3356, 0.1982, 0.6024, 0.083]
# [0.9748, 0.3308, 0.1488, 0.5522, 0.0512]
# [0.9704, 0.3612, 0.112, 0.6674, 0.0526]
# [0.9716, 0.2838, 0.1402, 0.7082, 0.0616]
# [0.9728, 0.2862, 0.1074, 0.6732, 0.0862]
# [0.9724, 0.3292, 0.2012, 0.6062, 0.0952]

# %% [markdown]
# # Classification vs Starting words groups

# %%
import json
json_path = r"../data_input/trait_activating_questions.json"
with open(json_path) as file:
    data = json.load(file)

# %%
import matplotlib.pyplot as plt
import numpy as np

traits = ['OPN', 'CON', 'EXT', 'AGR', 'NEU']
traits_ok = ['OPN', 'CON', 'EXT', 'AGR', 'ES']
categories = ['Openness', 'Conscientiousness', 'Extraversion', 'Agreeableness', 'Emotional stability']

for r_index,r_dir in enumerate(results_dirs):
    
    df = all_df[r_dir]
    
    for k,g in enumerate(model_names):

        gdf=df[df['model_name']==g]

        fig, axs = plt.subplots(5,1, sharex=False, sharey=False, figsize=(15,20), frameon=False)
        fig.subplots_adjust(left=0.25)
        for i,(cat,trait) in enumerate(zip(categories, traits_ok)):

            starting_texts = data[cat] 
            cdf = gdf[gdf['category']==cat]

            scores = []
            for stext in starting_texts:
                mask = cdf['text'].apply(lambda x:x.startswith(stext))
                x = cdf[mask]['pred_c' + trait]
                x = x.sum()/len(x)
                scores.append(x)
                
            axs[i].barh(starting_texts, scores)

            axs[i].set_title(cat)

            axs[i].invert_yaxis()

            axs[i].set_xlim([0,1])

        plt.savefig(os.path.join(output_sent_folder[r_index+1], f'model_{g}_text.jpg'))

# %% [markdown]
# # Saving all results

# %%
# !tar -czvf output_trait_activating_answers.tar.gz /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers
# Out:
# tar: Removing leading `/' from member names
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/personality_by_nsents.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_3/
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_3/model_gpt2_text.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_3/model_op_350m_text.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_3/model_gpt2_clf_vs_groups.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_3/trait_ES_higher.xlsx
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_3/model_gpt2_large_clf_vs_groups.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_3/trait_ES_lower.xlsx
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_3/model_xlnet_large.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_3/trait_CON_higher.xlsx
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_3/trait_AGR_higher.xlsx
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_3/model_xlnet_large_text.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_3/model_gpt2_medium_clf_vs_groups.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_3/trait_CON_lower.xlsx
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_3/model_xlnet_text.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_3/model_xlnet_clf_vs_groups.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_3/model_op_125m_text.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_3/model_op_350m_clf_vs_groups.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_3/trait_EXT_higher.xlsx
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_3/trait_OPN_higher.xlsx
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_3/model_gpt2_medium.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_3/model_op_125m.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_3/model_xlnet_large_clf_vs_groups.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_3/model_op_13b_text.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_3/model_gpt2.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_3/model_op_125m_clf_vs_groups.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_3/model_op_13b_clf_vs_groups.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_3/model_gpt2_large.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_3/model_op_350m.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_3/trait_AGR_lower.xlsx
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_3/model_gpt2_medium_text.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_3/model_xlnet.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_3/model_gpt2_large_text.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_3/trait_OPN_lower.xlsx
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_3/trait_EXT_lower.xlsx
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_3/model_op_13b.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_2/
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_2/model_gpt2_text.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_2/model_op_350m_text.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_2/model_gpt2_clf_vs_groups.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_2/trait_ES_higher.xlsx
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_2/model_gpt2_large_clf_vs_groups.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_2/trait_ES_lower.xlsx
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_2/model_xlnet_large.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_2/trait_CON_higher.xlsx
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_2/trait_AGR_higher.xlsx
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_2/model_xlnet_large_text.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_2/model_gpt2_medium_clf_vs_groups.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_2/trait_CON_lower.xlsx
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_2/model_xlnet_text.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_2/model_xlnet_clf_vs_groups.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_2/model_op_125m_text.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_2/model_op_350m_clf_vs_groups.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_2/trait_EXT_higher.xlsx
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_2/trait_OPN_higher.xlsx
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_2/model_gpt2_medium.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_2/model_op_125m.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_2/model_xlnet_large_clf_vs_groups.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_2/model_op_13b_text.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_2/model_gpt2.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_2/model_op_125m_clf_vs_groups.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_2/model_op_13b_clf_vs_groups.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_2/model_gpt2_large.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_2/model_op_350m.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_2/trait_AGR_lower.xlsx
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_2/model_gpt2_medium_text.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_2/model_xlnet.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_2/model_gpt2_large_text.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_2/trait_OPN_lower.xlsx
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_2/trait_EXT_lower.xlsx
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_2/model_op_13b.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_1/
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_1/model_gpt2_text.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_1/model_op_350m_text.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_1/model_gpt2_clf_vs_groups.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_1/trait_ES_higher.xlsx
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_1/model_gpt2_large_clf_vs_groups.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_1/trait_ES_lower.xlsx
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_1/model_xlnet_large.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_1/trait_CON_higher.xlsx
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_1/trait_AGR_higher.xlsx
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_1/model_xlnet_large_text.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_1/model_gpt2_medium_clf_vs_groups.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_1/trait_CON_lower.xlsx
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_1/model_xlnet_text.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_1/model_xlnet_clf_vs_groups.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_1/model_op_125m_text.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_1/model_op_350m_clf_vs_groups.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_1/trait_EXT_higher.xlsx
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_1/trait_OPN_higher.xlsx
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_1/model_gpt2_medium.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_1/model_op_125m.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_1/model_xlnet_large_clf_vs_groups.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_1/model_op_13b_text.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_1/model_gpt2.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_1/model_op_125m_clf_vs_groups.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_1/model_op_13b_clf_vs_groups.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_1/model_gpt2_large.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_1/model_op_350m.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_1/trait_AGR_lower.xlsx
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_1/model_gpt2_medium_text.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_1/model_xlnet.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_1/model_gpt2_large_text.jpg
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_1/trait_OPN_lower.xlsx
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_1/trait_EXT_lower.xlsx
# /petrobr/parceirosbr/bigoilict/users/cristian.villalobos/personality-prediction-from-text/notebooks/output_trait_activating_answers/sents_1/model_op_13b.jpg
